# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
census_tract = gpd.read_file('data/geo_export_e2cd3cf8-21c0-468e-9274-ad3af1e7d5c9.shp')

# %%
nyc_tree = pd.read_csv('data/2015_Street_Tree_Census_-_Tree_Data.csv')

# %%
census_tract.ntacode.value_counts()

# %%
nyc_tree.boro_ct.value_counts()
# Out:
# 5020801    3776
# 5017600    3245
# 5020803    2749
# 5020804    2723
# 5019800    2620
#            ...
# 3025902       7
# 1011300       6
# 2031900       4
# 3028502       4
# 5001800       2
# Name: boro_ct, Length: 2152, dtype: int64

# %%
census_tract.boro_ct201.value_counts()
# Out:
# 5000900    1
# 3013200    1
# 4068000    1
# 4027600    1
# 4042600    1
#           ..
# 3031702    1
# 3020500    1
# 3017900    1
# 3003500    1
# 1014801    1
# Name: boro_ct201, Length: 2165, dtype: int64

# %%
census_tract.columns
# Out:
# Index(['boro_code', 'boro_ct201', 'boro_name', 'cdeligibil', 'ct2010',
#        'ctlabel', 'ntacode', 'ntaname', 'puma', 'shape_area', 'shape_leng',
#        'geometry'],
#       dtype='object')

# %%
census_tract.ntaname.value_counts()
# Out:
# Canarsie                           34
# Borough Park                       28
# Bay Ridge                          28
# Flatlands                          27
# East New York                      27
#                                    ..
# Starrett City                       2
# Airport                             2
# Stuyvesant Town-Cooper Village      2
# Rikers Island                       1
# park-cemetery-etc-Staten Island     1
# Name: ntaname, Length: 195, dtype: int64

# %%
sorted(nyc_tree.nta_name.unique())
# Out:
# ['Allerton-Pelham Gardens',
#  "Annadale-Huguenot-Prince's Bay-Eltingville",
#  'Arden Heights',
#  'Astoria',
#  'Auburndale',
#  'Baisley Park',
#  'Bath Beach',
#  'Battery Park City-Lower Manhattan',
#  'Bay Ridge',
#  'Bayside-Bayside Hills',
#  'Bedford',
#  'Bedford Park-Fordham North',
#  'Bellerose',
#  'Belmont',
#  'Bensonhurst East',
#  'Bensonhurst West',
#  'Borough Park',
#  'Breezy Point-Belle Harbor-Rockaway Park-Broad Channel',
#  'Briarwood-Jamaica Hills',
#  'Brighton Beach',
#  'Bronxdale',
#  'Brooklyn Heights-Cobble Hill',
#  'Brownsville',
#  'Bushwick North',
#  'Bushwick South',
#  'Cambria Heights',
#  'Canarsie',
#  'Carroll Gardens-Columbia Street-Red Hook',
#  'Central Harlem North-Polo Grounds',
#  'Central Harlem South',
#  'Charleston-Richmond Valley-Tottenville',
#  'Chinatown',
#  'Claremont-Bathgate',
#  'Clinton',
#  'Clinton Hill',
#  'Co-op City',
#  'College Point',
#  'Corona',
#  'Crotona Park East',
#  'Crown Heights North',
# ...

# %%
sorted(census_tract.ntaname.unique())
# Out:
# ['Airport',
#  'Allerton-Pelham Gardens',
#  "Annadale-Huguenot-Prince's Bay-Eltingville",
#  'Arden Heights',
#  'Astoria',
#  'Auburndale',
#  'Baisley Park',
#  'Bath Beach',
#  'Battery Park City-Lower Manhattan',
#  'Bay Ridge',
#  'Bayside-Bayside Hills',
#  'Bedford',
#  'Bedford Park-Fordham North',
#  'Bellerose',
#  'Belmont',
#  'Bensonhurst East',
#  'Bensonhurst West',
#  'Borough Park',
#  'Breezy Point-Belle Harbor-Rockaway Park-Broad Channel',
#  'Briarwood-Jamaica Hills',
#  'Brighton Beach',
#  'Bronxdale',
#  'Brooklyn Heights-Cobble Hill',
#  'Brownsville',
#  'Bushwick North',
#  'Bushwick South',
#  'Cambria Heights',
#  'Canarsie',
#  'Carroll Gardens-Columbia Street-Red Hook',
#  'Central Harlem North-Polo Grounds',
#  'Central Harlem South',
#  'Charleston-Richmond Valley-Tottenville',
#  'Chinatown',
#  'Claremont-Bathgate',
#  'Clinton',
#  'Clinton Hill',
#  'Co-op City',
#  'College Point',
#  'Corona',
#  'Crotona Park East',
#  'Crown Heights North',
# ...

# %%
census_tract.ntaname.value_counts()
# Out:
# Canarsie                           34
# Borough Park                       28
# Bay Ridge                          28
# Flatlands                          27
# East New York                      27
#                                    ..
# Starrett City                       2
# Airport                             2
# Stuyvesant Town-Cooper Village      2
# Rikers Island                       1
# park-cemetery-etc-Staten Island     1
# Name: ntaname, Length: 195, dtype: int64

# %%
neighborhoods = census_tract.dissolve(by='ntaname')

# %%
#neighborhoods.

# %%
neighborhoods.shape
# Out:
# (195, 11)

# %%
census_tract.shape
# Out:
# (2165, 12)

# %%
census_tract.plot(figsize=(14, 10))
# Out:
# <AxesSubplot:>

# %%
neighborhoods.plot(figsize=(14, 10))
# Out:
# <AxesSubplot:>

# %%
census_tract.dissolve(by='boro_name').plot(figsize=(14, 10))
# Out:
# <AxesSubplot:>

# %%
neighborhoods.shape
# Out:
# (195, 11)

# %%
nyc_tree.nta_name.value_counts()
# Out:
# Annadale-Huguenot-Prince's Bay-Eltingville    12969
# Great Kills                                   10734
# Bayside-Bayside Hills                          9780
# East New York                                  9607
# Rossville-Woodrow                              9251
#                                               ...
# Manhattanville                                  913
# Parkchester                                     790
# Starrett City                                   688
# West Brighton                                   481
# Stuyvesant Town-Cooper Village                  447
# Name: nta_name, Length: 188, dtype: int64

# %%
nyc_tree.tree_dbh.mean()
# Out:
# 11.27978701000895

# %%
nyc_tree.loc[nyc_tree.nta_name == 'Great Kills']['tree_dbh'].mean()
# Out:
# 10.452953232718464

# %%
nyc_tree['counter'] = 1

# %%
neighborhood_trees = nyc_tree.groupby('nta_name').sum()

# %%
neighborhood_trees.sort_values(by='counter')
# Out:
#                                                tree_id    block_id  tree_dbh  \
# nta_name
# Stuyvesant Town-Cooper Village                98553494    47249970      4553
# West Brighton                                134352654   103551865      5192
# Starrett City                                367203141   140043862      8643
# Parkchester                                  188737521   402004948      8366
# Manhattanville                               171273469   102198630      6618
# ...                                                ...         ...       ...
# Rossville-Woodrow                           3386853170  3814162459     84150
# East New York                               3828283779  1942322781     75625
# Bayside-Bayside Hills                       3633434748  3151010071    137783
# Great Kills                                 3558694275  4447706936    112202
# Annadale-Huguenot-Prince's Bay-Eltingville  5916916573  5355575848    120539
#
# ...

# %%
neighborhood_trees[neighborhood_trees.index == 'Great Kills']
# Out:
#                 tree_id    block_id  tree_dbh  stump_diam   postcode  \
# nta_name
# Great Kills  3558694275  4447706936    112202        3380  110655588
#
#              community board  borocode  cncldist  st_assem  st_senate  \
# nta_name
# Great Kills          5399202     53670    547434    673230     257616
#
#                  boro_ct       latitude      longitude          x_sp  \
# nta_name
# Great Kills  53827979904  435277.826323 -795955.445627  1.010934e+10
#
#                      y_sp  council district  census tract           bin  \
# nta_name
# Great Kills  1.504616e+09          545319.0   156993344.0  5.410143e+10
#
#                       bbl  counter
# nta_name
# Great Kills  5.378385e+13    10734

# %%
neighborhood_trees_2 = nyc_tree.groupby('nta_name').sum()

# %%
neighborhood_trees_2[neighborhood_trees_2.index == 'Great Kills']
# Out:
#                 tree_id    block_id  tree_dbh  stump_diam   postcode  \
# nta_name
# Great Kills  3558694275  4447706936    112202        3380  110655588
#
#              community board  borocode  cncldist  st_assem  st_senate  \
# nta_name
# Great Kills          5399202     53670    547434    673230     257616
#
#                  boro_ct       latitude      longitude          x_sp  \
# nta_name
# Great Kills  53827979904  435277.826323 -795955.445627  1.010934e+10
#
#                      y_sp  council district  census tract           bin  \
# nta_name
# Great Kills  1.504616e+09          545319.0   156993344.0  5.410143e+10
#
#                       bbl  counter
# nta_name
# Great Kills  5.378385e+13    10734

# %%
small_tree = neighborhood_trees_2[['tree_dbh', 'counter']]

# %%
neighborhoods.index
# Out:
# Index(['Airport', 'Allerton-Pelham Gardens',
#        'Annadale-Huguenot-Prince's Bay-Eltingville', 'Arden Heights',
#        'Astoria', 'Auburndale', 'Baisley Park', 'Bath Beach',
#        'Battery Park City-Lower Manhattan', 'Bay Ridge',
#        ...
#        'Windsor Terrace', 'Woodhaven', 'Woodlawn-Wakefield', 'Woodside',
#        'Yorkville', 'park-cemetery-etc-Bronx', 'park-cemetery-etc-Brooklyn',
#        'park-cemetery-etc-Manhattan', 'park-cemetery-etc-Queens',
#        'park-cemetery-etc-Staten Island'],
#       dtype='object', name='ntaname', length=195)

# %%
#combo_tree = pd.merge(neighborhoods, neighborhood_trees_2, on='')

# %%
combo_tree = neighborhoods.join(small_tree)

# %%
combo_tree.shape
# Out:
# (195, 13)

# %%
small_tree.shape
# Out:
# (188, 2)

# %%
neighborhoods.shape
# Out:
# (195, 11)

# %%
combo_tree.counter.isna().sum()
# Out:
# 7

# %%
other_combo = small_tree.join(neighborhoods)

# %%
other_combo.shape
# Out:
# (188, 13)

# %%
neighborhoods.plot(figsize=(8, 6))
# Out:
# <AxesSubplot:>

# %%
type(neighborhoods)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
type(other_combo)
# Out:
# pandas.core.frame.DataFrame

# %%
gpd_other_combo = gpd.GeoDataFrame(other_combo)

# %%
gpd_other_combo.plot(column='counter', figsize=(14, 10), legend=True)
# Out:
# <AxesSubplot:>

# %%
nyc_tree.health.value_counts()
# Out:
# Good    528850
# Fair     96504
# Poor     26818
# Name: health, dtype: int64

# %%
nyc_tree_practice = nyc_tree.loc[nyc_tree.status == 'Alive']

# %%
nyc_tree_practice

# %%
# nyc_tree.health.apply(lambda x: 2 if x=='Good' else (1 if x=='Fair' else 0))

# %%
nyc_tree['poor_trees'] = nyc_tree.health.apply(lambda x: 1 if x=='Poor' else 0)
poor_trees_df = nyc_tree.groupby('nta_name').sum()

# %%
poor_trees_df
# Out:
#                                                tree_id    block_id  tree_dbh  \
# nta_name
# Allerton-Pelham Gardens                     1369633455  1970285030     50632
# Annadale-Huguenot-Prince's Bay-Eltingville  5916916573  5355575848    120539
# Arden Heights                               2862960864  2930672883     67183
# Astoria                                     1404140313  1324378723     43214
# Auburndale                                  2703011079  1710875305     77802
# ...                                                ...         ...       ...
# Windsor Terrace                              392282288   522287022     28567
# Woodhaven                                   2350144461  1321043903     65665
# Woodlawn-Wakefield                          1290894865  2104435404     54207
# Woodside                                    1032452626   840427626     30456
# Yorkville                                    503138482   244878090     20937
#
# ...

# %%
nyc_tree.loc[(nyc_tree.nta_name == 'Astoria') & (nyc_tree.health == 'Poor')]
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 1208     172429    301204  08/24/2015         9           0   OnCurb  Alive
# 1888     200751    300790  09/03/2015         4           0   OnCurb  Alive
# 3831     167825    300527  08/23/2015         4           0   OnCurb  Alive
# 9491     206641    300686  09/06/2015         2           0   OnCurb  Alive
# 11435    202986    301134  09/04/2015         5           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 675686   172432    301203  08/24/2015         4           0   OnCurb  Alive
# 675759   150221    301162  08/16/2015         2           0   OnCurb  Alive
# 681210   167955    300568  08/23/2015        15           0   OnCurb  Alive
# 681451   154581    300796  08/17/2015         4           0   OnCurb  Alive
# 683056   172438    301222  08/24/2015        16           0   OnCurb  Alive
#
# ...

# %%
poor_trees_df.columns
# Out:
# Index(['tree_id', 'block_id', 'tree_dbh', 'stump_diam', 'postcode',
#        'community board', 'borocode', 'cncldist', 'st_assem', 'st_senate',
#        'boro_ct', 'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl', 'counter', 'poor_trees'],
#       dtype='object')

# %%
small_poor_trees = poor_trees_df[['tree_dbh', 'counter', 'poor_trees']]

# %%
small_poor_trees
# Out:
#                                             tree_dbh  counter  poor_trees
# nta_name
# Allerton-Pelham Gardens                        50632     3843         139
# Annadale-Huguenot-Prince's Bay-Eltingville    120539    12969         800
# Arden Heights                                  67183     6999         280
# Astoria                                        43214     4393         133
# Auburndale                                     77802     5332         185
# ...                                              ...      ...         ...
# Windsor Terrace                                28567     2290          57
# Woodhaven                                      65665     4260         106
# Woodlawn-Wakefield                             54207     4083         103
# Woodside                                       30456     2739         109
# Yorkville                                      20937     2269         191
#
# [188 rows x 3 columns]

# %%
other_combo_2 = small_poor_trees.join(neighborhoods)

# %%
gpd_other_combo_2 = gpd.GeoDataFrame(other_combo_2)

# %%
gpd_other_combo_2
# Out:
#                                             tree_dbh  counter  poor_trees  \
# nta_name
# Allerton-Pelham Gardens                        50632     3843         139
# Annadale-Huguenot-Prince's Bay-Eltingville    120539    12969         800
# Arden Heights                                  67183     6999         280
# Astoria                                        43214     4393         133
# Auburndale                                     77802     5332         185
# ...                                              ...      ...         ...
# Windsor Terrace                                28567     2290          57
# Woodhaven                                      65665     4260         106
# Woodlawn-Wakefield                             54207     4083         103
# Woodside                                       30456     2739         109
# Yorkville                                      20937     2269         191
#
# ...

# %%
gpd_other_combo_2.plot(column='poor_trees', figsize=(8, 6), legend=True, cmap='Reds');

# %%
gpd_other_combo.plot(column='counter', figsize=(8, 6), legend=True, cmap='Greens');

# %%
nyc_tree.borough.value_counts()
# Out:
# Queens           250551
# Brooklyn         177293
# Staten Island    105318
# Bronx             85203
# Manhattan         65423
# Name: borough, dtype: int64

# %%
nyc_tree.groupby('spc_latin').count().sort_values(by='counter', ascending=False).counter
# Out:
# spc_latin
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: counter, Length: 132, dtype: int64

# %%
nyc_tree.groupby('spc_latin').count().sort_values(by='counter', ascending=False)
# Out:
#                                     tree_id  block_id  created_at  tree_dbh  \
# spc_latin
# Platanus x acerifolia                 87014     87014       87014     87014
# Gleditsia triacanthos var. inermis    64264     64264       64264     64264
# Pyrus calleryana                      58931     58931       58931     58931
# Quercus palustris                     53185     53185       53185     53185
# Acer platanoides                      34189     34189       34189     34189
# ...                                     ...       ...         ...       ...
# Pinus nigra                              37        37          37        37
# Pinus rigida                             33        33          33        33
# Maclura pomifera                         29        29          29        29
# Pinus sylvestris                         25        25          25        25
# Pinus virginiana                         10        10          10        10
#
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 14))
ax.pie(nyc_tree.groupby('spc_latin').count().sort_values(by='counter', ascending=False).counter,
                                                colors=sns.color_palette('bright'));

# %%
top_trees = list(nyc_tree.groupby('spc_latin').count().sort_values(by='counter', ascending=False).iloc[:10].index)

# %%
for name, group in nyc_tree.groupby('spc_latin'):
    if name in top_trees:
        print(name)
# Out:
# Acer platanoides
# Ginkgo biloba
# Gleditsia triacanthos var. inermis
# Platanus x acerifolia
# Prunus
# Pyrus calleryana
# Quercus palustris
# Styphnolobium japonicum
# Tilia cordata
# Zelkova serrata

# %%
# fig, ax = plt.subplots(figsize=(20, 14))
# ax.pie(nyc_tree.groupby('spc_latin').count().sort_values(by='counter', ascending=False).counter,
#                                                 colors=sns.color_palette('bright'));

# %%
nyc_tree.shape
# Out:
# (683788, 47)

# %%
nyc_tree.groupby('spc_latin')['counter'].count().nlargest(15)
# Out:
# spc_latin
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
# Tilia cordata                         29742
# Prunus                                29279
# Zelkova serrata                       29258
# Ginkgo biloba                         21024
# Styphnolobium japonicum               19338
# Acer rubrum                           17246
# Fraxinus pennsylvanica                16251
# Tilia americana                       13530
# Acer saccharinum                      12277
# Liquidambar styraciflua               10657
# Name: counter, dtype: int64

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 10))
ax1 = (nyc_tree.groupby('spc_latin')['counter'].count().nlargest(15).plot(ax=ax1, kind='pie', colors=sns.color_palette('deep'),
       labels=nyc_tree.groupby('spc_latin')['counter'].count().nlargest(15).index,
       autopct='%1.0f%%', labeldistance=.9)
       .set_title('Composition of NYC Tree Population'))
ax2 = (nyc_tree.loc[nyc_tree.health == 'Poor'].groupby('spc_latin')['counter'].count().nlargest(15).plot(ax=ax2, kind='pie',
       colors=sns.color_palette('deep'),
       labels=nyc_tree.loc[nyc_tree.health == 'Poor'].groupby('spc_latin')['counter'].count().nlargest(15).index,
       autopct='%1.0f%%',labeldistance=.9).set_title('Composition of NYC Trees in Poor Health'));

# %%
nyc_tree.status.value_counts()
# Out:
# Alive    652173
# Stump     17654
# Dead      13961
# Name: status, dtype: int64

# %%
nyc_tree.spc_latin.isna().sum()
# Out:
# 31619

# %%
nyc_tree_3 = nyc_tree.loc[nyc_tree.status=='Alive']

# %%
nyc_tree_3.spc_latin.isna().sum()
# Out:
# 5

# %%
nyc_tree_3.loc[nyc_tree_3.health == 'Poor'].groupby('spc_latin')['counter'].count().nlargest(15)
# Out:
# spc_latin
# Acer platanoides                      3779
# Platanus x acerifolia                 2198
# Pyrus calleryana                      2089
# Tilia cordata                         1720
# Prunus                                1305
# Quercus palustris                     1235
# Gleditsia triacanthos var. inermis    1190
# Ginkgo biloba                         1118
# Acer rubrum                            896
# Zelkova serrata                        782
# Tilia americana                        742
# Acer                                   639
# Styphnolobium japonicum                616
# Acer saccharinum                       559
# Acer platanoides 'Crimson King'        450
# Name: counter, dtype: int64

# %%
nyc_tree_3.spc_latin[20:26]
# Out:
# 20    Gleditsia triacanthos var. inermis
# 21    Gleditsia triacanthos var. inermis
# 22                       Quercus phellos
# 23                   Acer pseudoplatanus
# 24                       Quercus phellos
# 25                          Acer ginnala
# Name: spc_latin, dtype: object

# %%
for item in nyc_tree.spc_latin:
    if item in list(nyc_tree_3.groupby('spc_latin')['counter'].count().nlargest(15).index):
        print(item)
    else:
        print('what')
# Out:
# Acer rubrum
# Quercus palustris
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# Tilia americana
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# Tilia americana
# Gleditsia triacanthos var. inermis
# Platanus x acerifolia
# Platanus x acerifolia
# Platanus x acerifolia
# Platanus x acerifolia
# Platanus x acerifolia
# Platanus x acerifolia
# Gleditsia triacanthos var. inermis
# Ginkgo biloba
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# Ginkgo biloba
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# what
# what
# what
# what
# Platanus x acerifolia
# Platanus x acerifolia
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# Gleditsia triacanthos var. inermis
# ...

# %%
nyc_tree.loc[(nyc_tree.spc_latin=='Acer') & (nyc_tree.health=='Poor')]
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 12793    125785    214587  08/07/2015        19           0   OnCurb  Alive
# 12907    169385    301572  08/23/2015        12           0   OnCurb  Alive
# 13023    166738    348650  08/22/2015         6           0   OnCurb  Alive
# 13031    166840    348841  08/22/2015         6           0   OnCurb  Alive
# 13256    159916    103398  08/19/2015        18           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 659581   166553    348460  08/22/2015        18           0   OnCurb  Alive
# 667721   131205    302186  08/09/2015         5           0   OnCurb  Alive
# 668373   166517    348459  08/22/2015        16           0   OnCurb  Alive
# 670206   164046    337791  08/21/2015        10           0   OnCurb  Alive
# 674661   166839    348841  08/22/2015         6           0   OnCurb  Alive
#
# ...

# %%
common_names = nyc_tree.groupby('spc_common').sum()

# %%
common_names
# Out:
#                            tree_id    block_id  tree_dbh  stump_diam  \
# spc_common
# 'Schubert' chokecherry  1748097258  1591820641     23914           0
# American beech            91903209    85143303      1761           0
# American elm            2461725636  2386630387     95327           0
# American hophornbeam     359036637   340040659      6539           0
# American hornbeam        572637638   513833040      7466           0
# ...                            ...         ...       ...         ...
# weeping willow           110237944    92608046      4455           0
# white ash                378915151   362384465     14206           0
# white oak                565215270   501712410     12575           0
# white pine                71270481    70437625      2539           0
# willow oak              1049178115   868184035     39097           0
#
#                         postcode  community board  borocode  cncldist  \
# spc_common
# ...

# %%
common_names['%_poor'] = common_names.poor_trees / common_names.counter

# %%
242/4888
# Out:
# 0.049509001636661214

# %%
21/273
# Out:
# 0.07692307692307693

# %%
common_names
# Out:
#                            tree_id    block_id  tree_dbh  stump_diam  \
# spc_common
# 'Schubert' chokecherry  1748097258  1591820641     23914           0
# American beech            91903209    85143303      1761           0
# American elm            2461725636  2386630387     95327           0
# American hophornbeam     359036637   340040659      6539           0
# American hornbeam        572637638   513833040      7466           0
# ...                            ...         ...       ...         ...
# weeping willow           110237944    92608046      4455           0
# white ash                378915151   362384465     14206           0
# white oak                565215270   501712410     12575           0
# white pine                71270481    70437625      2539           0
# willow oak              1049178115   868184035     39097           0
#
#                         postcode  community board  borocode  cncldist  \
# spc_common
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax = gpd.GeoDataFrame(common_names).plot(ax=ax, column='%_poor', legend=True, cmap='Reds')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11928/573034427.py in <module>
#       1 fig, ax = plt.subplots(figsize=(10, 8))
# ----> 2 ax = gpd.GeoDataFrame(common_names).plot(ax=ax, column='%_poor', legend=True, cmap='Reds')
#
# ~\anaconda3\envs\geo_env\lib\site-packages\geopandas\plotting.py in __call__(self, *args, **kwargs)
#     948         kind = kwargs.pop("kind", "geo")
#     949         if kind == "geo":
# --> 950             return plot_dataframe(data, *args, **kwargs)
#     951         if kind in self._pandas_kinds:
#     952             # Access pandas plots
#
# ~\anaconda3\envs\geo_env\lib\site-packages\geopandas\plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     813
# ...

# %%
sns.barplot(x=common_names['%_poor'].nlargest(15), y=common_names['%_poor'].nlargest(15).index)

# %%
common_names['%_poor'].nlargest(15)

# %%
common_names.sort_values('%_poor', ascending=False)

# %%
common_names.counter.mean()

# %%
common_names.shape

# %%
nyc_tree.status.value_counts()

# %%
nyc_tree.shape

# %%
132 * 4940.674242424242

# %%
common_names.shape

# %%
common_names.sort_values('%_poor', ascending=False)[:15]

# %%
common_names.counter.mean()

# %%
common_names.counter.describe()

# %%
common_names.counter.std()

# %%
common_names.sort_values('counter')

# %%
#common_names.sort_values('%_poor', ascending=False)[:15]
common_names.loc[common_names.counter >= 100].sort_values('%_poor', ascending=False)[:15]

# %%
common_names.sort_values('%_poor', ascending=False)[:15]

# %%
common_names.loc[['Norway maple']]['poor_trees']

# %%
common_names.poor_trees.sum()

# %%
nyc_tree.health.value_counts()

# %%
common_names.loc[['Norway maple']]['poor_trees'] / common_names.poor_trees.sum()

# %%
sns.barplot(x=)
